# %% [markdown]
# # Sentiment Analysis using Regex on Riliv App Reviews
#
# This notebook demonstrates how to apply regular expressions (regex) to extract important words from app reviews for sentiment analysis.
#
# ### Dataset Overview:
# We are using review data from the Riliv Mental Health app, with columns such as:
# - `content`: Review text
# - `score`: Rating score
# - `sentiment_rating`: Sentiment (Positive/Negative)
# - `wordCount`: Number of words before stopword removal
# - `tweet_with_stopwords`: Review text with stopwords
# - `wordCount_after_stopwords`: Number of words after stopword removal
# - `tweet_stemmed`: Review text after stemming
#
# ### Regex Examples:
# Below are some examples of regex patterns applied to the reviews.
#
# 1. **Words starting with a capital letter**:
#    - `^[A-Z]\w+`
#
# 2. **Finding mental health-related terms**:
#    - `(terapi|psikolog|depresi|cemas|stres|mental)`
#
# 3. **Positive sentiment words**:
#    - `(baik|membantu|efektif|mudah|puas|bagus)`
#
# 4. **Negative sentiment words**:
#    - `(buruk|sulit|tidak puas|mengecewakan|jelek)`
#
# 5. **Numeric values (e.g., ratings or durations)**:
#    - `\b\d+\b`
#
# 6. **Phrases containing 'tidak' followed by another word**:
#    - `tidak \w+`
#
# 7. **Questions (sentences ending with '?')**:
#    - `\w+\?`
#
# 8. **Terms related to app features**:
#    - `(fitur|aplikasi|fungsi|antarmuka|login)`
#
# 9. **Abbreviations (e.g., BPJS, NIK)**:
#    - `\b[A-Z]{2,}\b`
#
# 10. **Quoted phrases**:
#    - `\"[^\"]+\"`

# %%
import pandas as pd

# Load the dataset
df_rilivrev = pd.read_csv('/content/rilivrev_final.csv', sep=';')

# Display the first few rows of the dataset
df_rilivrev.head()
# Out:
#                                              content  score sentiment_rating  \
# 0  riliv keren, karena kasih aku banyak pengalama...      5         Positive
# 1  bagus!!! aplikasi nya bagus banget gak ada cac...      5         Positive
# 2                                                 ok      5         Positive
# 3                                          apk bagus      5         Positive
# 4                    membantu sekalii, di hari harii      5         Positive
#
#    wordCount                               tweet_with_stopwords  \
# 0         23  riliv keren kasih pengalaman pelajaran kesehat...
# 1         20  bagus    aplikasi bagus gak cacat recommended
# 2          1                                                 ok
# 3          2                                          apk bagus
# 4          6                             membantu sekalii harii
#
#    wordCount_after_stopwords  \
# 0                         10
# 1                          6
# 2                          1
# 3                          2
# 4                          3
#
#                                        tweet_stemmed
# 0  riliv keren kasih pengalaman pelajaran kesehat...
# 1             bagu aplikasi bagu gak cacat recommend
# 2                                                 ok
# 3                                           apk bagu
# 4                             membantu sekalii harii

# %%
import re

# Example: Find reviews that mention 'terapi', 'psikolog', 'depresi', etc.
mental_health_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(terapi|psikolog|depresi|cemas|stres|mental)', case=False, na=False)]

# Display the first few matching reviews
mental_health_reviews.head()
# Out:
# <ipython-input-2-0ef69f99ef99>:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mental_health_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(terapi|psikolog|depresi|cemas|stres|mental)', case=False, na=False)]
#                                               content  score sentiment_rating  \
# 0   riliv keren, karena kasih aku banyak pengalama...      5         Positive
# 12  adanya apk ini cukup membantu bagi saya. menu ...      5         Positive
# 20  aplikasi yang sangat luar biasa. membantu meri...      5         Positive
# 27             sangat membantu untuk kesehatan mental      5         Positive
# 33  riliv membantu sekali untuk dealing with menta...      5         Positive
#
#     wordCount                               tweet_with_stopwords  \
# 0          23  riliv keren kasih pengalaman pelajaran kesehat...
# 12         28  apk membantu  menu fitur beragam tenaga psikol...
# 20         23  aplikasi  membantu meringankan  tips tips meng...
# 27          5                          membantu kesehatan mental
# 33         12  riliv membantu dealing with mental issue cepat...
#
#     wordCount_after_stopwords  \
# 0                          10
# 12                         14
# 20                          9
# 27                          3
# 33                          8
#
#                                         tweet_stemmed
# 0   riliv keren kasih pengalaman pelajaran kesehat...
# 12  apk membantu menu fitur beragam tenaga psikolo...
# 20  aplikasi membantu meringankan tip tip menguran...
# 27                          membantu kesehatan mental
# 33   riliv membantu deal with mental issu cepat mudah

# %%
# Example: Find reviews that contain positive words like 'baik', 'membantu', etc.
positive_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(baik|membantu|efektif|mudah|puas|bagus)', case=False, na=False)]
positive_reviews.head()
# Out:
# <ipython-input-4-91c032895410>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   positive_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(baik|membantu|efektif|mudah|puas|bagus)', case=False, na=False)]
#                                              content  score sentiment_rating  \
# 1  bagus!!! aplikasi nya bagus banget gak ada cac...      5         Positive
# 3                                          apk bagus      5         Positive
# 4                    membantu sekalii, di hari harii      5         Positive
# 5                             sangat baik,membantuku      5         Positive
# 6                        bener bener sangat membantu      5         Positive
#
#    wordCount                               tweet_with_stopwords  \
# 1         20  bagus    aplikasi bagus gak cacat recommended
# 3          2                                          apk bagus
# 4          6                             membantu sekalii harii
# 5          4                                         membantuku
# 6          4                               bener bener membantu
#
#    wordCount_after_stopwords                           tweet_stemmed
# 1                          6  bagu aplikasi bagu gak cacat recommend
# 3                          2                                apk bagu
# 4                          3                  membantu sekalii harii
# 5                          1                              membantuku
# 6                          3                    bener bener membantu

# %%
# Example: Find reviews that contain negative words like 'buruk', 'sulit', etc.
negative_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(buruk|sulit|tidak puas|mengecewakan|jelek)', case=False, na=False)]
negative_reviews.head()
# Out:
# <ipython-input-5-faae315500c6>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   negative_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(buruk|sulit|tidak puas|mengecewakan|jelek)', case=False, na=False)]
#                                                content  score  \
# 41   bagus sih aplikasi nya bisa mencari berbagai b...      5
# 85   aplikasi ini sangat bagus,saya ingin berterima...      5
# 94   apl nya bagus sangat membantu saya yg kesulita...      5
# 116  jelek banget aplikasi nya lama banget bales ny...      1
# 217  mohon maaf sebelumnya, tapi untuk pengalaman p...      1
#
#     sentiment_rating  wordCount  \
# 41          Positive         37
# 85          Positive         18
# 94          Positive         16
# 116         Negative         27
# 217         Negative         33
#
#                                   tweet_with_stopwords  \
# 41   bagus aplikasi mencari bantuan membayar mencar...
# 85   aplikasi bagus berterimakasiih riliv membantu ...
# 94   apl bagus membantu kesulitan apresiasi terimak...
# 116  jelek aplikasi bales buang buang duit lega bik...
# 217  mohon maaf pengalaman pribadi  aplikasi memili...
#
#      wordCount_after_stopwords  \
# 41                          14
# 85                           7
# 94                           8
# 116                         14
# 217                         16
#
#                                          tweet_stemmed
# 41   bagu aplikasi mencari bantuan membayar mencari...
# 85   aplikasi bagu berterimakasiih riliv membantu m...
# 94   apl bagu membantu kesulitan apresiasi terimaka...
# 116  jelek aplikasi bale buang buang duit lega biki...
# 217  mohon maaf pengalaman pribadi aplikasi memilik...

# %%
# Example: Find reviews that contain numeric values
numeric_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'\b\d+\b', na=False)]
numeric_reviews.head()
# Out:
#                                                content  score  \
# 109  masih belum bisa memberikan bintang 5, karena ...      4
# 124  udah bayar sesi konseling sesi cuma 40 menit t...      1
# 140   coba untuk saat ini saya kasih bintang 3 dlu ya.      3
# 146  bintang 1 dulu karena baru pertama pakai semog...      1
# 165  jika aku memberikan bintang 5 berarti apk ini ...      5
#
#     sentiment_rating  wordCount  \
# 109         Positive         15
# 124         Negative         27
# 140          Neutral         11
# 146         Negative         10
# 165         Positive         33
#
#                                   tweet_with_stopwords  \
# 109                             bintang  fitur layanan
# 124  udah bayar sesi konseling sesi  menit tp blm d...
# 140                           coba kasih bintang  dlu
# 146                     bintang  pakai semoga membantu
# 165  bintang  apk bagus meditasi kondisi psikologis...
#
#      wordCount_after_stopwords  \
# 109                          3
# 124                         14
# 140                          4
# 146                          4
# 165                         12
#
#                                          tweet_stemmed
# 109                              bintang fitur layanan
# 124  udah bayar sesi konsel sesi menit tp blm dires...
# 140                             coba kasih bintang dlu
# 146                      bintang pakai semoga membantu
# 165  bintang apk bagu meditasi kondisi psikolog fit...

# %%
# Example: Find reviews that contain 'tidak' followed by another word
negation_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'tidak \w+', case=False, na=False)]
negation_reviews.head()
# Out:
#                                                content  score  \
# 24   hallo... saya sering sekali mendengar meditasi...      5
# 41   bagus sih aplikasi nya bisa mencari berbagai b...      5
# 42   aplikasi yang benar-benar mendukung bagi orang...      5
# 89   tidak auto refresh saat ada chat baru! sering ...      4
# 156  aplikasinya sangat membantu, mempermudah pengg...      5
#
#     sentiment_rating  wordCount  \
# 24          Positive         40
# 41          Positive         37
# 42          Positive         12
# 89          Positive         19
# 156         Positive         75
#
#                                   tweet_with_stopwords  \
# 24   hallo  mendengar meditasi lelap riliv  saran k...
# 41   bagus aplikasi mencari bantuan membayar mencar...
# 42       aplikasi benarbenar mendukung orangorang baik
# 89             auto refresh chat  masuk masuk chatnya
# 156  aplikasinya membantu mempermudah pengguna  pen...
#
#      wordCount_after_stopwords  \
# 24                          20
# 41                          14
# 42                           5
# 89                           6
# 156                         28
#
#                                          tweet_stemmed
# 24   hallo mendengar meditasi lelap riliv saran kua...
# 41   bagu aplikasi mencari bantuan membayar mencari...
# 42       aplikasi benarbenar mendukung orangorang baik
# 89               auto refresh chat masuk masuk chatnya
# 156  aplikasinya membantu mempermudah pengguna peng...

# %%
# Example: Find reviews that end with a question mark
question_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'\w+\?', na=False)]
question_reviews.head()
# Out:
#                                                content  score  \
# 32   kak ini kenapa ya koq aplikasi ke tutup sendir...      4
# 200                                 bayar ta app nya??      4
# 210  berawal mau resechedule jadwal psikolog ga bis...      1
# 250  ini gbisa untuk anak 14-16?? pembayaran jg cmn...      5
# 309  kaka ga bisa masuk room kenapa???????? baru se...      5
#
#     sentiment_rating  wordCount  \
# 32          Positive         17
# 200         Positive          6
# 210         Negative         62
# 250         Positive         33
# 309         Positive         21
#
#                                   tweet_with_stopwords  \
# 32     kak koq aplikasi tutup liat riwayat konseling
# 200                                     bayar ta app
# 210  resechedule jadwal psikolog ga  uninstall pas ...
# 250  gbisa anak    pembayaran jg cmn doang  plis nj...
# 309          kaka ga masuk room         sesi  ga pakai
#
#      wordCount_after_stopwords  \
# 32                           7
# 200                          3
# 210                         32
# 250                         21
# 309                          7
#
#                                          tweet_stemmed
# 32          kak koq aplikasi tutup liat riwayat konsel
# 200                                       bayar ta app
# 210  resechedul jadwal psikolog ga uninstal pa lg m...
# 250  gbisa anak pembayaran jg cmn doang pli njayi s...
# 309                   kaka ga masuk room sesi ga pakai

# %%
# Example: Find reviews that mention app features like 'fitur', 'aplikasi', etc.
feature_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(fitur|aplikasi|fungsi|antarmuka|login)', case=False, na=False)]
feature_reviews.head()
# Out:
# <ipython-input-9-a16281aba36a>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   feature_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(fitur|aplikasi|fungsi|antarmuka|login)', case=False, na=False)]
#                                               content  score sentiment_rating  \
# 1   bagus!!! aplikasi nya bagus banget gak ada cac...      5         Positive
# 9   aplikasi riliv sangat bagus dan bermanfaat bag...      5         Positive
# 12  adanya apk ini cukup membantu bagi saya. menu ...      5         Positive
# 16  aku yg ga punya tempat cerita jadi merasa dipe...      5         Positive
# 18                     aplikasi nya bagus bisa curhat      5         Positive
#
#     wordCount                               tweet_with_stopwords  \
# 1          20  bagus    aplikasi bagus gak cacat recommended
# 9          16  aplikasi riliv bagus bermanfaat kondisi keseha...
# 12         28  apk membantu  menu fitur beragam tenaga psikol...
# 16         20  ga cerita dipeduliin aplikasi  thanks for ever...
# 18          5                              aplikasi bagus curhat
#
#     wordCount_after_stopwords  \
# 1                           6
# 9                           6
# 12                         14
# 16                          8
# 18                          3
#
#                                         tweet_stemmed
# 1              bagu aplikasi bagu gak cacat recommend
# 9    aplikasi riliv bagu bermanfaat kondisi kesehatan
# 12  apk membantu menu fitur beragam tenaga psikolo...
# 16  ga cerita dipeduliin aplikasi thank for everyt...
# 18                               aplikasi bagu curhat

# %%
# Example: Find reviews that contain abbreviations like BPJS, NIK, etc.
abbreviation_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'\b[A-Z]{2,}\b', na=False)]
abbreviation_reviews.head()
# Out:
# Empty DataFrame
# Columns: [content, score, sentiment_rating, wordCount, tweet_with_stopwords, wordCount_after_stopwords, tweet_stemmed]
# Index: []

# %%
# Example: Find reviews that contain quoted phrases
quoted_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'\"[^\"]+\"', na=False)]
quoted_reviews.head()
# Out:
#                                                content  score  \
# 210  berawal mau resechedule jadwal psikolog ga bis...      1
# 242  aplikasinya bagus tapi load-nya lamaaaaaaaaa b...      1
# 245  bufferingnya parah sekali selalu ada tulisan "...      2
# 248  halo riliv! aplikasi kalian sebenarnya bagus. ...      1
# 249  setelah download selesai & waktu pertama kali ...      2
#
#     sentiment_rating  wordCount  \
# 210         Negative         62
# 242         Negative         30
# 245         Negative         19
# 248         Negative         63
# 249         Negative         20
#
#                                   tweet_with_stopwords  \
# 210  resechedule jadwal psikolog ga  uninstall pas ...
# 242  aplikasinya bagus loadnya lamaaaaaaaaa jaringa...
# 245  bufferingnya parah tulisan  proses gagal  jari...
# 248  halo riliv  aplikasi bagus  really appreciated...
# 249  selesai  kali daftar google email muncul pesan...
#
#      wordCount_after_stopwords  \
# 210                         32
# 242                         15
# 245                          9
# 248                         27
# 249                         10
#
#                                          tweet_stemmed
# 210  resechedul jadwal psikolog ga uninstal pa lg m...
# 242  aplikasinya bagu loadnya lamaaaaaaaaa jaringan...
# 245  bufferingnya parah tulisan prose gagal jaringa...
# 248  halo riliv aplikasi bagu realli appreci disaya...
# 249  selesai kali daftar googl email muncul pesan p...

# %%
# Example: Find reviews containing more than 2 negative words
negative_words = r'\b(buruk|sulit|tidak puas|mengecewakan|jelek)\b'
multiple_negative_reviews = df_rilivrev[df_rilivrev['content'].str.contains(rf'({negative_words}.*){2,}', case=False, na=False)]
multiple_negative_reviews.head()
# Out:
# <ipython-input-13-b6a4dd9c47d0>:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   multiple_negative_reviews = df_rilivrev[df_rilivrev['content'].str.contains(rf'({negative_words}.*){2,}', case=False, na=False)]
# Empty DataFrame
# Columns: [content, score, sentiment_rating, wordCount, tweet_with_stopwords, wordCount_after_stopwords, tweet_stemmed]
# Index: []

# %%
# Example: Find reviews containing 'tidak' followed by an adjective
adjectives = r'(baik|buruk|bagus|jelek|efektif|sulit|mudah|puas|membantu)'
negation_with_adjective_reviews = df_rilivrev[df_rilivrev['content'].str.contains(rf'tidak\s+{adjectives}', case=False, na=False)]
negation_with_adjective_reviews.head()
# Out:
# <ipython-input-14-b55827a2fc9a>:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   negation_with_adjective_reviews = df_rilivrev[df_rilivrev['content'].str.contains(rf'tidak\s+{adjectives}', case=False, na=False)]
#                                                 content  score  \
# 42    aplikasi yang benar-benar mendukung bagi orang...      5
# 1513  kalo buat pengangguran seperti saya bagaimna b...      1
# 1709  kok loading terus ya gak bisa kebuka cuman iko...      1
# 1814                                        tidak buruk      3
#
#      sentiment_rating  wordCount  \
# 42           Positive         12
# 1513         Negative         48
# 1709         Negative         17
# 1814          Neutral          2
#
#                                    tweet_with_stopwords  \
# 42        aplikasi benarbenar mendukung orangorang baik
# 1513  kalo pengangguran bagaimna curhat  blom curhat...
# 1709  loading gak kebuka cuman ikon aplikasi doang m...
# 1814                                              buruk
#
#       wordCount_after_stopwords  \
# 42                            5
# 1513                         22
# 1709                          9
# 1814                          1
#
#                                           tweet_stemmed
# 42        aplikasi benarbenar mendukung orangorang baik
# 1513  kalo pengangguran bagaimna curhat blom curhat ...
# 1709  load gak kebuka cuman ikon aplikasi doang meny...
# 1814                                              buruk

# %%
# Example: Find reviews with 'tetapi' or 'namun' indicating sentiment shift
sentiment_shift_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'\b(tetapi|namun)\b', case=False, na=False)]
sentiment_shift_reviews.head()
# Out:
# <ipython-input-15-64c0afa945e5>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   sentiment_shift_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'\b(tetapi|namun)\b', case=False, na=False)]
#                                                content  score  \
# 61   aplikasi ini sangat membantu dan responnya cuk...      5
# 307  sebenernya aplikasi ini bagus, namun gak tau k...      3
# 374  sudah lama instal aplikasi ini, tetapi baru me...      5
# 823  assalamualaikum.... terima kasih riliv aplikas...      5
# 858  belum satu hari saya menginstal aplikasi ini, ...      5
#
#     sentiment_rating  wordCount  \
# 61          Positive         21
# 307          Neutral         21
# 374         Positive         23
# 823         Positive         68
# 858         Positive         28
#
#                                   tweet_with_stopwords  \
# 61   aplikasi membantu responnya bagus  kali ngebug...
# 307  sebenernya aplikasi bagus gak tau knp gk akses...
# 374  instal aplikasi menyadari maksimalkan aplikasi...
# 823  assalamualaikum  terima kasih riliv aplikasi m...
# 858  menginstal aplikasi nyaman  berharap kedepanny...
#
#      wordCount_after_stopwords  \
# 61                          10
# 307                         11
# 374                          8
# 823                         27
# 858                          8
#
#                                          tweet_stemmed
# 61   aplikasi membantu responnya bagu kali ngebug b...
# 307  sebenernya aplikasi bagu gak tau knp gk aks fi...
# 374  instal aplikasi menyadari maksimalkan aplikasi...
# 823  assalamualaikum terima kasih riliv aplikasi me...
# 858  menginst aplikasi nyaman berharap kedepannya n...

# %%
# Example: Find reviews that compare two things (X better/worse than Y)
comparison_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'lebih\s+(baik|buruk)\s+dari', case=False, na=False)]
comparison_reviews.head()
# Out:
# <ipython-input-16-8db7d419e671>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   comparison_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'lebih\s+(baik|buruk)\s+dari', case=False, na=False)]
#                                                content  score  \
# 156  aplikasinya sangat membantu, mempermudah pengg...      5
# 313  aplikasi ini sangat membatuku, i love you rili...      5
# 826  saya senang sekali dengan aplikasi ini, karna ...      5
#
#     sentiment_rating  wordCount  \
# 156         Positive         75
# 313         Positive         38
# 826         Positive         21
#
#                                   tweet_with_stopwords  \
# 156  aplikasinya membantu mempermudah pengguna  pen...
# 313  aplikasi membatuku i love you riliv aplikasi i...
# 826  senang aplikasi karna merasakan sebelumnyauntu...
#
#      wordCount_after_stopwords  \
# 156                         28
# 313                         21
# 826                          9
#
#                                          tweet_stemmed
# 156  aplikasinya membantu mempermudah pengguna peng...
# 313  aplikasi membatuku i love you riliv aplikasi i...
# 826  senang aplikasi karna merasakan sebelumnyauntu...

# %%
# Example: Find reviews with superlative words like 'paling' or 'sangat'
superlative_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'\b(paling|sangat)\b', case=False, na=False)]
superlative_reviews.head()
# Out:
# <ipython-input-17-f5ff014db0c3>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   superlative_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'\b(paling|sangat)\b', case=False, na=False)]
#                                               content  score sentiment_rating  \
# 5                              sangat baik,membantuku      5         Positive
# 6                         bener bener sangat membantu      5         Positive
# 9   aplikasi riliv sangat bagus dan bermanfaat bag...      5         Positive
# 14    sangat membantu karena sering malas journaling.      5         Positive
# 19                      lebih lengkap sangat membantu      5         Positive
#
#     wordCount                               tweet_with_stopwords  \
# 5           4                                         membantuku
# 6           4                               bener bener membantu
# 9          16  aplikasi riliv bagus bermanfaat kondisi keseha...
# 14          7                         membantu malas journaling
# 19          4                                   lengkap membantu
#
#     wordCount_after_stopwords  \
# 5                           1
# 6                           3
# 9                           6
# 14                          3
# 19                          2
#
#                                        tweet_stemmed
# 5                                         membantuku
# 6                               bener bener membantu
# 9   aplikasi riliv bagu bermanfaat kondisi kesehatan
# 14                             membantu mala journal
# 19                                  lengkap membantu

# %%
# Example: Find reviews with double negation like 'tidak pernah tidak'
double_negation_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'tidak\s+\w+\s+tidak', case=False, na=False)]
double_negation_reviews.head()
# Out:
# Empty DataFrame
# Columns: [content, score, sentiment_rating, wordCount, tweet_with_stopwords, wordCount_after_stopwords, tweet_stemmed]
# Index: []

# %%
# Example: Find reviews containing URLs or email addresses
url_or_email_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(https?://\S+|\w+@\w+\.\w+)', na=False)]
url_or_email_reviews.head()
# Out:
# <ipython-input-19-67f642e206b9>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   url_or_email_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'(https?://\S+|\w+@\w+\.\w+)', na=False)]
# Empty DataFrame
# Columns: [content, score, sentiment_rating, wordCount, tweet_with_stopwords, wordCount_after_stopwords, tweet_stemmed]
# Index: []

# %%
# Example: Find reviews that consist of a single word
single_word_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'^\w+$', na=False)]
single_word_reviews.head()
# Out:
#    content  score sentiment_rating  wordCount tweet_with_stopwords  \
# 2       ok      5         Positive          1                   ok
# 7    bagys      5         Positive          1                bagys
# 13   sukak      5         Positive          1                sukak
# 23     top      5         Positive          1                  top
# 25   bagus      5         Positive          1                bagus
#
#     wordCount_after_stopwords tweet_stemmed
# 2                           1            ok
# 7                           1          bagi
# 13                          1         sukak
# 23                          1           top
# 25                          1          bagu

# %%
# Example: Find reviews with repeated exclamation marks for emphasis
repeated_exclamation_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'!{2,}', na=False)]
repeated_exclamation_reviews.head()
# Out:
#                                                content  score  \
# 1    bagus!!! aplikasi nya bagus banget gak ada cac...      5
# 87                   seru bgt gratis n gaada iklann!!!      5
# 183  aplikasi nya lumayan membantu , cuma ada beber...      4
# 469  saya pribadi sangat menyukai aplikasi ini keti...      5
# 709           panduan meditasi yang baik!! terimakasih      5
#
#     sentiment_rating  wordCount  \
# 1           Positive         20
# 87          Positive          9
# 183         Positive         47
# 469         Positive         83
# 709         Positive          7
#
#                                   tweet_with_stopwords  \
# 1    bagus    aplikasi bagus gak cacat recommended
# 87                       seru gratis n gaada iklann
# 183  aplikasi lumayan membantu kekurangan gak berpe...
# 469  pribadi menyukai aplikasi malas jurnaling buku...
# 709                     panduan meditasi   terimakasih
#
#      wordCount_after_stopwords  \
# 1                            6
# 87                           5
# 183                         19
# 469                         35
# 709                          3
#
#                                          tweet_stemmed
# 1               bagu aplikasi bagu gak cacat recommend
# 87                           seru grati n gaada iklann
# 183  aplikasi lumayan membantu kekurangan gak berpe...
# 469  pribadi menyukai aplikasi mala jurnal buku mud...
# 709                       panduan meditasi terimakasih

# %%
# Example: Find reviews with unusually long words (potential typos or spam)
long_word_reviews = df_rilivrev[df_rilivrev['content'].str.contains(r'\w{15,}', na=False)]
long_word_reviews.head()
# Out:
#                                                content  score  \
# 85   aplikasi ini sangat bagus,saya ingin berterima...      5
# 210  berawal mau resechedule jadwal psikolog ga bis...      1
# 278  sangat membantu sekali, disaat gapunya temen c...      5
# 613  aplikasi yang sangat membantu dalam menenangka...      5
# 784  tambahin juga ya min kayak kita bercerita di p...      3
#
#     sentiment_rating  wordCount  \
# 85          Positive         18
# 210         Negative         62
# 278         Positive         19
# 613         Positive         29
# 784          Neutral         69
#
#                                   tweet_with_stopwords  \
# 85   aplikasi bagus berterimakasiih riliv membantu ...
# 210  resechedule jadwal psikolog ga  uninstall pas ...
# 278  membantu disaat gapunya temen cerita aplikasi ...
# 613  aplikasi membantu menenangkan pikiran i like i...
# 784  tambahin min kayak bercerita publik gitu komen...
#
#      wordCount_after_stopwords  \
# 85                           7
# 210                         32
# 278                         10
# 613                         14
# 784                         19
#
#                                          tweet_stemmed
# 85   aplikasi bagu berterimakasiih riliv membantu m...
# 210  resechedul jadwal psikolog ga uninstal pa lg m...
# 278  membantu disaat gapunya temen cerita aplikasi ...
# 613  aplikasi membantu menenangkan pikiran i like i...
# 784  tambahin min kayak bercerita publik gitu komen...
